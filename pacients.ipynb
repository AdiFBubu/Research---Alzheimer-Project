# %%
import requests
import os

# Define the range of value1 (GSM IDs) and value2 (IDs)
value1_start = 1570253
value1_end = 1570585
value2_start = 6420
value2_end = 6752

url_template = "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc={value1}&id={value2}&db=GeoDb_blob122"
output_dir = "geo_downloads"
os.makedirs(output_dir, exist_ok=True)

v2 = value2_start - 1
for v1 in range(value1_start, value1_end + 1):
    gsm = f"GSM{v1}"
    v2 = v2 + 1
    url = url_template.format(value1=gsm, value2=v2)
    print(url)
    try:
        resp = requests.get(url, timeout=20)
        resp.raise_for_status()
        # Save to file
        filename = os.path.join(output_dir, f"{gsm}_{v2}.txt")
        with open(filename, "w", encoding="utf-8") as f:
            f.write(resp.text)
    except Exception as e:
        print(f"Failed to download {gsm}, {v2}: {e}")

print("Download complete.")
# Out:
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570253&id=6420&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570254&id=6421&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570255&id=6422&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570256&id=6423&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570257&id=6424&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570258&id=6425&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570259&id=6426&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570260&id=6427&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570261&id=6428&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570262&id=6429&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570263&id=6430&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570264&id=6431&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570265&id=6432&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570266&id=6433&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570267&id=6434&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570268&id=6435&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570269&id=6436&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570270&id=6437&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570271&id=6438&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570272&id=6439&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570273&id=6440&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570274&id=6441&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570275&id=6442&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570276&id=6443&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570277&id=6444&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570278&id=6445&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570279&id=6446&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570280&id=6447&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570281&id=6448&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570282&id=6449&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570283&id=6450&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570284&id=6451&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570285&id=6452&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570286&id=6453&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570287&id=6454&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570288&id=6455&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570289&id=6456&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570290&id=6457&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570291&id=6458&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570292&id=6459&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570293&id=6460&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570294&id=6461&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570295&id=6462&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570296&id=6463&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570297&id=6464&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570298&id=6465&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570299&id=6466&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570300&id=6467&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570301&id=6468&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570302&id=6469&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570303&id=6470&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570304&id=6471&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570305&id=6472&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570306&id=6473&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570307&id=6474&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570308&id=6475&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570309&id=6476&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570310&id=6477&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570311&id=6478&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570312&id=6479&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570313&id=6480&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570314&id=6481&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570315&id=6482&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570316&id=6483&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570317&id=6484&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570318&id=6485&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570319&id=6486&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570320&id=6487&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570321&id=6488&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570322&id=6489&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570323&id=6490&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570324&id=6491&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570325&id=6492&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570326&id=6493&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570327&id=6494&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570328&id=6495&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570329&id=6496&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570330&id=6497&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570331&id=6498&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570332&id=6499&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570333&id=6500&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570334&id=6501&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570335&id=6502&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570336&id=6503&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570337&id=6504&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570338&id=6505&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570339&id=6506&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570340&id=6507&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570341&id=6508&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570342&id=6509&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570343&id=6510&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570344&id=6511&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570345&id=6512&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570346&id=6513&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570347&id=6514&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570348&id=6515&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570349&id=6516&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570350&id=6517&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570351&id=6518&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570352&id=6519&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570353&id=6520&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570354&id=6521&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570355&id=6522&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570356&id=6523&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570357&id=6524&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570358&id=6525&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570359&id=6526&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570360&id=6527&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570361&id=6528&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570362&id=6529&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570363&id=6530&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570364&id=6531&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570365&id=6532&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570366&id=6533&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570367&id=6534&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570368&id=6535&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570369&id=6536&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570370&id=6537&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570371&id=6538&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570372&id=6539&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570373&id=6540&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570374&id=6541&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570375&id=6542&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570376&id=6543&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570377&id=6544&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570378&id=6545&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570379&id=6546&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570380&id=6547&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570381&id=6548&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570382&id=6549&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570383&id=6550&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570384&id=6551&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570385&id=6552&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570386&id=6553&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570387&id=6554&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570388&id=6555&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570389&id=6556&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570390&id=6557&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570391&id=6558&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570392&id=6559&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570393&id=6560&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570394&id=6561&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570395&id=6562&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570396&id=6563&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570397&id=6564&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570398&id=6565&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570399&id=6566&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570400&id=6567&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570401&id=6568&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570402&id=6569&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570403&id=6570&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570404&id=6571&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570405&id=6572&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570406&id=6573&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570407&id=6574&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570408&id=6575&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570409&id=6576&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570410&id=6577&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570411&id=6578&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570412&id=6579&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570413&id=6580&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570414&id=6581&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570415&id=6582&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570416&id=6583&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570417&id=6584&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570418&id=6585&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570419&id=6586&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570420&id=6587&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570421&id=6588&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570422&id=6589&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570423&id=6590&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570424&id=6591&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570425&id=6592&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570426&id=6593&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570427&id=6594&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570428&id=6595&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570429&id=6596&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570430&id=6597&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570431&id=6598&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570432&id=6599&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570433&id=6600&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570434&id=6601&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570435&id=6602&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570436&id=6603&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570437&id=6604&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570438&id=6605&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570439&id=6606&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570440&id=6607&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570441&id=6608&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570442&id=6609&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570443&id=6610&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570444&id=6611&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570445&id=6612&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570446&id=6613&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570447&id=6614&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570448&id=6615&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570449&id=6616&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570450&id=6617&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570451&id=6618&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570452&id=6619&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570453&id=6620&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570454&id=6621&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570455&id=6622&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570456&id=6623&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570457&id=6624&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570458&id=6625&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570459&id=6626&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570460&id=6627&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570461&id=6628&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570462&id=6629&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570463&id=6630&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570464&id=6631&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570465&id=6632&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570466&id=6633&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570467&id=6634&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570468&id=6635&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570469&id=6636&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570470&id=6637&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570471&id=6638&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570472&id=6639&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570473&id=6640&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570474&id=6641&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570475&id=6642&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570476&id=6643&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570477&id=6644&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570478&id=6645&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570479&id=6646&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570480&id=6647&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570481&id=6648&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570482&id=6649&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570483&id=6650&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570484&id=6651&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570485&id=6652&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570486&id=6653&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570487&id=6654&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570488&id=6655&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570489&id=6656&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570490&id=6657&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570491&id=6658&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570492&id=6659&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570493&id=6660&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570494&id=6661&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570495&id=6662&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570496&id=6663&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570497&id=6664&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570498&id=6665&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570499&id=6666&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570500&id=6667&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570501&id=6668&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570502&id=6669&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570503&id=6670&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570504&id=6671&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570505&id=6672&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570506&id=6673&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570507&id=6674&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570508&id=6675&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570509&id=6676&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570510&id=6677&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570511&id=6678&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570512&id=6679&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570513&id=6680&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570514&id=6681&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570515&id=6682&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570516&id=6683&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570517&id=6684&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570518&id=6685&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570519&id=6686&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570520&id=6687&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570521&id=6688&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570522&id=6689&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570523&id=6690&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570524&id=6691&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570525&id=6692&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570526&id=6693&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570527&id=6694&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570528&id=6695&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570529&id=6696&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570530&id=6697&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570531&id=6698&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570532&id=6699&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570533&id=6700&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570534&id=6701&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570535&id=6702&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570536&id=6703&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570537&id=6704&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570538&id=6705&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570539&id=6706&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570540&id=6707&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570541&id=6708&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570542&id=6709&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570543&id=6710&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570544&id=6711&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570545&id=6712&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570546&id=6713&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570547&id=6714&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570548&id=6715&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570549&id=6716&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570550&id=6717&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570551&id=6718&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570552&id=6719&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570553&id=6720&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570554&id=6721&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570555&id=6722&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570556&id=6723&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570557&id=6724&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570558&id=6725&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570559&id=6726&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570560&id=6727&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570561&id=6728&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570562&id=6729&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570563&id=6730&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570564&id=6731&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570565&id=6732&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570566&id=6733&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570567&id=6734&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570568&id=6735&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570569&id=6736&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570570&id=6737&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570571&id=6738&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570572&id=6739&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570573&id=6740&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570574&id=6741&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570575&id=6742&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570576&id=6743&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570577&id=6744&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570578&id=6745&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570579&id=6746&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570580&id=6747&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570581&id=6748&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570582&id=6749&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570583&id=6750&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570584&id=6751&db=GeoDb_blob122
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1570585&id=6752&db=GeoDb_blob122
# Download complete.

# %%
import pandas as pd
import re
import os
from io import StringIO

def extract_idref_value(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    match = re.search(r'<pre>(.*?)</pre>', text, re.DOTALL | re.IGNORECASE)
    if not match:
        raise ValueError(f"No <pre> block found in {file_path}")
    pre_data = match.group(1)
    data_lines = [line for line in pre_data.splitlines() if line and not line.startswith('#')]
    for i, line in enumerate(data_lines):
        line_clean = re.sub(r'<.*?>', '', line).strip()
        if line_clean.startswith("ID_REF"):
            header_idx = i
            break
    else:
        raise ValueError(f"No header with ID_REF found in {file_path}")
    table_lines = data_lines[header_idx:]
    table_lines = [re.sub(r'<.*?>', '', l).strip() for l in table_lines]
    df = pd.read_csv(StringIO('\n'.join(table_lines)), sep='\t')
    df = df[['ID_REF', 'VALUE']]
    return df

# Gather all filenames in the folder
folder = "geo_downloads"
value_dfs = []
filenames = sorted([f for f in os.listdir(folder) if f.endswith(".txt")])  # Adjust box as needed

for f in filenames:
    abs_path = os.path.join(folder, f)
    sample_id = os.path.splitext(f)[0]  # Or extract GSM ID, as needed
    df = extract_idref_value(abs_path)
    df = df.rename(columns={"VALUE": sample_id})
    value_dfs.append(df)

# Merge all by 'ID_REF'
from functools import reduce
global_df = reduce(lambda left, right: pd.merge(left, right, on="ID_REF"), value_dfs)

global_df.to_csv("all_mice_GSE64398.csv", index=False)
print(global_df.head())
# Out:
#           ID_REF  GSM1570253_6420  GSM1570254_6421  GSM1570255_6422  \
# 0  0610005K03RIK          6.43230          6.49524          6.62031
# 1  0610006F02RIK          6.48671          6.70625          6.81477
# 2  0610006I08RIK         11.52560         11.49350         11.04880
# 3  0610006K04RIK          8.89335          8.89025          8.93425
# 4  0610007C21RIK         12.08650         11.91080         11.84890
#
#    GSM1570256_6423  GSM1570257_6424  GSM1570258_6425  GSM1570259_6426  \
# 0          6.63890          6.86916          6.51808          6.36677
# 1          6.70933          6.70996          6.55293          6.69918
# 2         11.33660         11.45820         12.15340         11.47650
# 3          8.81467          9.04093          9.57344          8.96465
# 4         11.97640         12.10390         12.49410         12.02650
#
#    GSM1570260_6427  GSM1570261_6428  ...  GSM1570576_6743  GSM1570577_6744  \
# 0          6.70498          6.89317  ...          6.55966          6.30184
# 1          6.59228          6.52274  ...          6.56499          6.63472
# 2         11.43370         11.28560  ...         11.27210         11.31590
# 3          8.81948          9.07514  ...          8.31111          8.62294
# 4         12.03200         12.15060  ...         11.89310         12.05900
#
#    GSM1570578_6745  GSM1570579_6746  GSM1570580_6747  GSM1570581_6748  \
# 0          6.64454          6.27616          6.62092          6.89864
# 1          6.48076          6.69013          6.62051          6.59761
# 2         11.70560         11.13250         11.53210         11.59300
# 3          9.46431          8.39157          9.22673          9.35089
# 4         12.11910         11.93950         12.04240         12.17790
#
#    GSM1570582_6749  GSM1570583_6750  GSM1570584_6751  GSM1570585_6752
# 0          6.68040          6.63137          6.36295          6.91588
# 1          6.75523          6.64000          6.55813          6.62477
# 2         11.52380         11.65390         11.27680         11.81480
# 3          9.28346          9.30094          8.22587          9.67369
# 4         12.15970         12.01490         11.71830         12.32770
#
# [5 rows x 334 columns]

# %%
import re
import pandas as pd
from pathlib import Path

EXPECTED_HEADER = [
    "Group",
    "Accession",
    "Title",
    "Source name",
    "Sample section",
    "Hybridisation day",
    "Characteristics",
    "Grown with",
    "Genotype",
]

def parse_txt_to_df(path: str | Path) -> pd.DataFrame:
    path = Path(path)
    with path.open("r", encoding="utf-8") as f:
        # Strip whitespace-only lines
        lines = [ln.strip() for ln in f if ln.strip() != ""]

    # Find the header line (starts with "Group")
    try:
        header_idx = next(
            i for i, ln in enumerate(lines) if ln.split("\t")[0].strip() == "Group"
        )
    except StopIteration:
        raise ValueError('Header line starting with "Group" not found')

    # Process records after header
    i = header_idx + 1
    rows: list[list[str]] = []

    while i < len(lines):
        # Each record starts with a line that's exactly "-"
        if lines[i] != "-":
            i += 1
            continue

        group = lines[i]  # "-"
        i += 1
        if i >= len(lines):
            break

        # Next line: 6 tab-separated fields
        part1 = lines[i].split("\t")
        i += 1
        if i >= len(lines):
            break

        # Next line: 2 tab-separated fields
        part2 = lines[i].split("\t")
        i += 1

        if len(part1) != 6 or len(part2) != 2:
            raise ValueError(
                f"Unexpected column counts for a record near line {i}. "
                f"Got part1={len(part1)} fields, part2={len(part2)} fields."
            )

        row = [group] + part1 + part2  # total 1 + 6 + 2 = 9 columns
        rows.append(row)

    df = pd.DataFrame(rows, columns=EXPECTED_HEADER)

    # Extract integer age from "Characteristics" (e.g., "age(weeks): 32" -> 32)
    df["Age_weeks"] = (
        df["Characteristics"].str.extract(r"(\d+)")[0].astype("Int64")
    )

    # Drop the original text column since you only want the integer age
    df = df.drop(columns=["Characteristics"])

    # Optional: parse the date and set dtypes you might want
    # df["Hybridisation day"] = pd.to_datetime(df["Hybridisation day"], errors="coerce")

    return df
# Usage:

df = parse_txt_to_df("geo_downloads/metadata.txt")
print(df.head())
df.to_csv("all_mice_GSE64398_metadata.csv", index=False)
# Out:
#   Group   Accession Title Source name Sample section Hybridisation day  \
# 0     -  GSM1570253   478         HIP              A        2013-03-04
# 1     -  GSM1570254   809         HIP              B        2013-03-04
# 2     -  GSM1570255  1462         HIP              C        2013-03-04
# 3     -  GSM1570256  1819         HIP              D        2013-03-04
# 4     -  GSM1570257  2155         HIP              E        2013-03-04
#
#    Grown with    Genotype  Age_weeks
# 0  HET_TASTPM  HET_TASTPM         32
# 1   HO_TASTPM   HO_TASTPM         16
# 2         TAU        WILD         32
# 3         TAU         TAU         16
# 4       TAS10        WILD         72

# %% [markdown]
# HUMAN

# %%
import pandas as pd
from io import StringIO

def read_group_dash_table(path):
    """
    Parse a table where each data row is preceded by a line with '-'
    indicating the 'Group' column value, and the actual row values are
    tab-separated on the next line.

    Assumes the first non-empty line is the tab-separated header including 'Group' as the first column.
    """
    with open(path, 'r', encoding='utf-8') as f:
        raw = f.read()

    # Keep non-empty lines, preserve tabs
    lines = [ln.rstrip('\r\n') for ln in raw.splitlines() if ln.strip()]

    if not lines:
        return pd.DataFrame()

    header = lines[0]  # must include 'Group' as first column
    record_lines = []
    i = 1
    n = len(lines)

    while i < n:
        if lines[i].strip() == '-':
            # The next non-empty line is the data row (tab-separated, without the Group value)
            j = i + 1
            while j < n and not lines[j].strip():
                j += 1
            if j >= n:
                break
            data_line = lines[j]
            # Prepend the group token to form a complete row
            record_lines.append(f"-\t{data_line}")
            i = j + 1
        else:
            # Skip any stray line (should not happen if the file strictly alternates '-' and data)
            i += 1

    table_text = header + '\n' + '\n'.join(record_lines)
    df = pd.read_csv(StringIO(table_text), sep='\t', dtype=str)
    return df

# Example usage:
# Save your content to 'pfc_metadata.txt' and run:
if __name__ == "__main__":
    df = read_group_dash_table("human/metadata.txt")

    # Optional: extract numeric age in years from 'Age (Ch2)' like '67 yrs'
    if 'Age (Ch2)' in df.columns:
        df['Age (Ch2)'] = (
            df['Age (Ch2)'].astype(str).str.extract(r'(\d+)', expand=False).astype(int)
        )
        
    print(df.head())
    
    df.to_csv("all_human_GSE33000_metadata.csv", index=False)
# Out:
#   Group   Accession  Title    Source name 1 Source name 2  \
# 0     -  GSM1423780  PFC_1  HBTRC_PF_Pool_1         PFC_1
# 1     -  GSM1423781  PFC_2  HBTRC_PF_Pool_2         PFC_2
# 2     -  GSM1423782  PFC_3  HBTRC_PF_Pool_3         PFC_3
# 3     -  GSM1423783  PFC_4  HBTRC_PF_Pool_4         PFC_4
# 4     -  GSM1423784  PFC_5  HBTRC_PF_Pool_5         PFC_5
#
#               Tissue (Ch1) Sample type (Ch1)             Tissue (Ch2)  \
# 0  prefrontal cortex brain         reference  prefrontal cortex brain
# 1  prefrontal cortex brain         reference  prefrontal cortex brain
# 2  prefrontal cortex brain         reference  prefrontal cortex brain
# 3  prefrontal cortex brain         reference  prefrontal cortex brain
# 4  prefrontal cortex brain         reference  prefrontal cortex brain
#
#    Age (Ch2) Gender (Ch2) Disease status (Ch2)
# 0         67       female  Alzheimer's disease
# 1         88         male  Alzheimer's disease
# 2         62         male  Alzheimer's disease
# 3         90       female  Alzheimer's disease
# 4         90       female  Alzheimer's disease

# %%
import requests
import os

# Define the range of value1 (GSM IDs) and value2 (IDs)
value1_start = 1423780
value1_end = 1424246
value2_start = 19975
value2_end = 20441

url_template = "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc={value1}&id={value2}&db=GeoDb_blob113"
output_dir = "human"
os.makedirs(output_dir, exist_ok=True)

v2 = value2_start - 1
for v1 in range(value1_start, value1_end + 1):
    gsm = f"GSM{v1}"
    v2 = v2 + 1
    url = url_template.format(value1=gsm, value2=v2)
    print(url)
    try:
        resp = requests.get(url, timeout=20)
        resp.raise_for_status()
        # Save to file
        filename = os.path.join(output_dir, f"{gsm}_{v2}.txt")
        with open(filename, "w", encoding="utf-8") as f:
            f.write(resp.text)
        exit(1)
    except Exception as e:
        print(f"Failed to download {gsm}, {v2}: {e}")

print("Download complete.")
# Out:
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423780&id=19975&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423781&id=19976&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423782&id=19977&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423783&id=19978&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423784&id=19979&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423785&id=19980&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423786&id=19981&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423787&id=19982&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423788&id=19983&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423789&id=19984&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423790&id=19985&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423791&id=19986&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423792&id=19987&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423793&id=19988&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423794&id=19989&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423795&id=19990&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423796&id=19991&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423797&id=19992&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423798&id=19993&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423799&id=19994&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423800&id=19995&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423801&id=19996&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423802&id=19997&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423803&id=19998&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423804&id=19999&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423805&id=20000&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423806&id=20001&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423807&id=20002&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423808&id=20003&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423809&id=20004&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423810&id=20005&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423811&id=20006&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423812&id=20007&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423813&id=20008&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423814&id=20009&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423815&id=20010&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423816&id=20011&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423817&id=20012&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423818&id=20013&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423819&id=20014&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423820&id=20015&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423821&id=20016&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423822&id=20017&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423823&id=20018&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423824&id=20019&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423825&id=20020&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423826&id=20021&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423827&id=20022&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423828&id=20023&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423829&id=20024&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423830&id=20025&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423831&id=20026&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423832&id=20027&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423833&id=20028&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423834&id=20029&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423835&id=20030&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423836&id=20031&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423837&id=20032&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423838&id=20033&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423839&id=20034&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423840&id=20035&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423841&id=20036&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423842&id=20037&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423843&id=20038&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423844&id=20039&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423845&id=20040&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423846&id=20041&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423847&id=20042&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423848&id=20043&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423849&id=20044&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423850&id=20045&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423851&id=20046&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423852&id=20047&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423853&id=20048&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423854&id=20049&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423855&id=20050&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423856&id=20051&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423857&id=20052&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423858&id=20053&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423859&id=20054&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423860&id=20055&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423861&id=20056&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423862&id=20057&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423863&id=20058&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423864&id=20059&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423865&id=20060&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423866&id=20061&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423867&id=20062&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423868&id=20063&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423869&id=20064&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423870&id=20065&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423871&id=20066&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423872&id=20067&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423873&id=20068&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423874&id=20069&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423875&id=20070&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423876&id=20071&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423877&id=20072&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423878&id=20073&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423879&id=20074&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423880&id=20075&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423881&id=20076&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423882&id=20077&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423883&id=20078&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423884&id=20079&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423885&id=20080&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423886&id=20081&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423887&id=20082&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423888&id=20083&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423889&id=20084&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423890&id=20085&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423891&id=20086&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423892&id=20087&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423893&id=20088&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423894&id=20089&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423895&id=20090&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423896&id=20091&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423897&id=20092&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423898&id=20093&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423899&id=20094&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423900&id=20095&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423901&id=20096&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423902&id=20097&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423903&id=20098&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423904&id=20099&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423905&id=20100&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423906&id=20101&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423907&id=20102&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423908&id=20103&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423909&id=20104&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423910&id=20105&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423911&id=20106&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423912&id=20107&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423913&id=20108&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423914&id=20109&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423915&id=20110&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423916&id=20111&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423917&id=20112&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423918&id=20113&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423919&id=20114&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423920&id=20115&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423921&id=20116&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423922&id=20117&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423923&id=20118&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423924&id=20119&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423925&id=20120&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423926&id=20121&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423927&id=20122&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423928&id=20123&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423929&id=20124&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423930&id=20125&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423931&id=20126&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423932&id=20127&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423933&id=20128&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423934&id=20129&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423935&id=20130&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423936&id=20131&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423937&id=20132&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423938&id=20133&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423939&id=20134&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423940&id=20135&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423941&id=20136&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423942&id=20137&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423943&id=20138&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423944&id=20139&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423945&id=20140&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423946&id=20141&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423947&id=20142&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423948&id=20143&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423949&id=20144&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423950&id=20145&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423951&id=20146&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423952&id=20147&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423953&id=20148&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423954&id=20149&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423955&id=20150&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423956&id=20151&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423957&id=20152&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423958&id=20153&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423959&id=20154&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423960&id=20155&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423961&id=20156&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423962&id=20157&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423963&id=20158&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423964&id=20159&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423965&id=20160&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423966&id=20161&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423967&id=20162&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423968&id=20163&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423969&id=20164&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423970&id=20165&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423971&id=20166&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423972&id=20167&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423973&id=20168&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423974&id=20169&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423975&id=20170&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423976&id=20171&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423977&id=20172&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423978&id=20173&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423979&id=20174&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423980&id=20175&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423981&id=20176&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423982&id=20177&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423983&id=20178&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423984&id=20179&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423985&id=20180&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423986&id=20181&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423987&id=20182&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423988&id=20183&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423989&id=20184&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423990&id=20185&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423991&id=20186&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423992&id=20187&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423993&id=20188&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423994&id=20189&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423995&id=20190&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423996&id=20191&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423997&id=20192&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423998&id=20193&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1423999&id=20194&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424000&id=20195&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424001&id=20196&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424002&id=20197&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424003&id=20198&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424004&id=20199&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424005&id=20200&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424006&id=20201&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424007&id=20202&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424008&id=20203&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424009&id=20204&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424010&id=20205&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424011&id=20206&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424012&id=20207&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424013&id=20208&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424014&id=20209&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424015&id=20210&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424016&id=20211&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424017&id=20212&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424018&id=20213&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424019&id=20214&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424020&id=20215&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424021&id=20216&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424022&id=20217&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424023&id=20218&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424024&id=20219&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424025&id=20220&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424026&id=20221&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424027&id=20222&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424028&id=20223&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424029&id=20224&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424030&id=20225&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424031&id=20226&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424032&id=20227&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424033&id=20228&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424034&id=20229&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424035&id=20230&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424036&id=20231&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424037&id=20232&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424038&id=20233&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424039&id=20234&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424040&id=20235&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424041&id=20236&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424042&id=20237&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424043&id=20238&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424044&id=20239&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424045&id=20240&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424046&id=20241&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424047&id=20242&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424048&id=20243&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424049&id=20244&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424050&id=20245&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424051&id=20246&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424052&id=20247&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424053&id=20248&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424054&id=20249&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424055&id=20250&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424056&id=20251&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424057&id=20252&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424058&id=20253&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424059&id=20254&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424060&id=20255&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424061&id=20256&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424062&id=20257&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424063&id=20258&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424064&id=20259&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424065&id=20260&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424066&id=20261&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424067&id=20262&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424068&id=20263&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424069&id=20264&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424070&id=20265&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424071&id=20266&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424072&id=20267&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424073&id=20268&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424074&id=20269&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424075&id=20270&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424076&id=20271&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424077&id=20272&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424078&id=20273&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424079&id=20274&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424080&id=20275&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424081&id=20276&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424082&id=20277&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424083&id=20278&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424084&id=20279&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424085&id=20280&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424086&id=20281&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424087&id=20282&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424088&id=20283&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424089&id=20284&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424090&id=20285&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424091&id=20286&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424092&id=20287&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424093&id=20288&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424094&id=20289&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424095&id=20290&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424096&id=20291&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424097&id=20292&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424098&id=20293&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424099&id=20294&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424100&id=20295&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424101&id=20296&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424102&id=20297&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424103&id=20298&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424104&id=20299&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424105&id=20300&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424106&id=20301&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424107&id=20302&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424108&id=20303&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424109&id=20304&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424110&id=20305&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424111&id=20306&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424112&id=20307&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424113&id=20308&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424114&id=20309&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424115&id=20310&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424116&id=20311&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424117&id=20312&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424118&id=20313&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424119&id=20314&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424120&id=20315&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424121&id=20316&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424122&id=20317&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424123&id=20318&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424124&id=20319&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424125&id=20320&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424126&id=20321&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424127&id=20322&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424128&id=20323&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424129&id=20324&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424130&id=20325&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424131&id=20326&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424132&id=20327&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424133&id=20328&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424134&id=20329&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424135&id=20330&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424136&id=20331&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424137&id=20332&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424138&id=20333&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424139&id=20334&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424140&id=20335&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424141&id=20336&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424142&id=20337&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424143&id=20338&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424144&id=20339&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424145&id=20340&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424146&id=20341&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424147&id=20342&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424148&id=20343&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424149&id=20344&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424150&id=20345&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424151&id=20346&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424152&id=20347&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424153&id=20348&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424154&id=20349&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424155&id=20350&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424156&id=20351&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424157&id=20352&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424158&id=20353&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424159&id=20354&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424160&id=20355&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424161&id=20356&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424162&id=20357&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424163&id=20358&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424164&id=20359&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424165&id=20360&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424166&id=20361&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424167&id=20362&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424168&id=20363&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424169&id=20364&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424170&id=20365&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424171&id=20366&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424172&id=20367&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424173&id=20368&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424174&id=20369&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424175&id=20370&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424176&id=20371&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424177&id=20372&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424178&id=20373&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424179&id=20374&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424180&id=20375&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424181&id=20376&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424182&id=20377&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424183&id=20378&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424184&id=20379&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424185&id=20380&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424186&id=20381&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424187&id=20382&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424188&id=20383&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424189&id=20384&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424190&id=20385&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424191&id=20386&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424192&id=20387&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424193&id=20388&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424194&id=20389&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424195&id=20390&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424196&id=20391&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424197&id=20392&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424198&id=20393&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424199&id=20394&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424200&id=20395&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424201&id=20396&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424202&id=20397&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424203&id=20398&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424204&id=20399&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424205&id=20400&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424206&id=20401&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424207&id=20402&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424208&id=20403&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424209&id=20404&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424210&id=20405&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424211&id=20406&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424212&id=20407&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424213&id=20408&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424214&id=20409&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424215&id=20410&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424216&id=20411&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424217&id=20412&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424218&id=20413&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424219&id=20414&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424220&id=20415&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424221&id=20416&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424222&id=20417&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424223&id=20418&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424224&id=20419&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424225&id=20420&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424226&id=20421&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424227&id=20422&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424228&id=20423&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424229&id=20424&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424230&id=20425&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424231&id=20426&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424232&id=20427&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424233&id=20428&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424234&id=20429&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424235&id=20430&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424236&id=20431&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424237&id=20432&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424238&id=20433&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424239&id=20434&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424240&id=20435&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424241&id=20436&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424242&id=20437&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424243&id=20438&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424244&id=20439&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424245&id=20440&db=GeoDb_blob113
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=GSM1424246&id=20441&db=GeoDb_blob113
# Download complete.

# %%
import os
import pandas as pd
import re
from io import StringIO

def extract_idref_value_from_geo_html(file_path):
    """Extracts ID_REF and VALUE columns from GEO-style HTML file."""
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()

    # Extract <pre>...</pre>
    match = re.search(r'<pre>(.*?)</pre>', text, re.DOTALL|re.IGNORECASE)
    if not match:
        raise ValueError(f"No <pre> block found in {file_path}")
    pre_data = match.group(1)

    # Remove comment and empty lines
    lines = [line for line in pre_data.splitlines() if line and not line.startswith('#')]
    
    # Find header index
    for i, line in enumerate(lines):
        line_clean = re.sub(r'<.*?>', '', line).strip()
        if line_clean.startswith("ID_REF"):
            header_idx = i
            break
    else:
        raise ValueError(f'No "ID_REF" header in {file_path}')
    
    # Keep only actual data table, strip HTML tags
    table_lines = lines[header_idx:]
    table_lines = [re.sub(r'<.*?>', '', l).strip() for l in table_lines]

    # Read into DataFrame
    df = pd.read_csv(StringIO('\n'.join(table_lines)), sep='\t')
    if 'ID_REF' not in df or 'VALUE' not in df:
        raise ValueError(f"Validation error for columns in {file_path}")
    return df[['ID_REF', 'VALUE']]

# Directory containing your files
folder = 'human'
dfs = []
names = []

for fname in sorted(os.listdir(folder)):
    fpath = os.path.join(folder, fname)
    if not os.path.isfile(fpath) or fpath == 'metadata.txt':
        continue
    try:
        df = extract_idref_value_from_geo_html(fpath)
        name = os.path.splitext(fname)[0]
        df = df.rename(columns={'VALUE': name})
        dfs.append(df)
        names.append(name)
    except Exception as e:
        print(f"Skipping {fname}: {e}")

if not dfs:
    raise RuntimeError('No valid files found.')

# Merge on ID_REF
from functools import reduce
merged_df = reduce(lambda left, right: pd.merge(left, right, on="ID_REF"), dfs)

print(merged_df.head())
# Save if wanted
# merged_df.to_csv("all_human_GSE33000.tsv", sep='\t', index=False)
# Out:
# Skipping metadata.txt: No <pre> block found in human\metadata.txt
#         ID_REF  GSM1423780_19975  GSM1423781_19976  GSM1423782_19977  \
# 0  10019475365         -0.016184          0.027599         -0.089661
# 1  10019481149         -0.017105         -0.023574          0.044863
# 2  10019495284          0.077440         -0.058746         -0.120759
# 3  10019687586          0.033595          0.032914         -0.030928
# 4  10019713746         -0.001819          0.032487         -0.015073
#
#    GSM1423783_19978  GSM1423784_19979  GSM1423785_19980  GSM1423786_19981  \
# 0         -0.020493         -0.051699          0.075485         -0.046606
# 1          0.003438         -0.064108         -0.053226         -0.071823
# 2          0.072692         -0.051002         -0.183919         -0.074997
# 3         -0.033051         -0.049156         -0.011204          0.072451
# 4         -0.010303          0.063070          0.113860         -0.055590
#
#    GSM1423787_19982  GSM1423788_19983  ...  GSM1424237_20432  \
# 0          0.111980          0.018505  ...          0.001105
# 1         -0.051699         -0.024906  ...          0.006312
# 2         -0.090709          0.049640  ...         -0.188096
# 3          0.126576          0.078031  ...         -0.056582
# 4          0.127236          0.056135  ...         -0.013275
#
#    GSM1424238_20433  GSM1424239_20434  GSM1424240_20435  GSM1424241_20436  \
# 0          0.046370          0.068043          0.203844          0.042579
# 1          0.021401          0.013530          0.029631          0.020914
# 2         -0.234009         -0.210803         -0.304265         -0.169539
# 3         -0.032147         -0.034396         -0.123908         -0.012879
# 4          0.049071          0.059656          0.172214          0.024506
#
#    GSM1424242_20437  GSM1424243_20438  GSM1424244_20439  GSM1424245_20440  \
# 0          0.018263          0.121809         -0.034938          0.073973
# 1          0.014296          0.010552         -0.010118          0.017207
# 2         -0.173077         -0.258932         -0.159735         -0.182124
# 3          0.005083         -0.144517         -0.068259         -0.074872
# 4          0.030127          0.085608         -0.009837          0.057851
#
#    GSM1424246_20441
# 0          0.068453
# 1          0.062803
# 2         -0.267266
# 3         -0.023523
# 4          0.059051
#
# [5 rows x 468 columns]

# %%
import pandas as pd

# df = pd.read_csv("all_human_GSE33000.csv")  # or sep=","
df = pd.read_csv("all_mice_GSE64398.csv")  # or sep=","
new_cols = [df.columns[0]] + [c.split("_")[0] for c in df.columns[1:]]
df.columns = new_cols

# df.to_csv("all_human_GSE33000.csv", index=False)
df.to_csv("all_mice_GSE64398.csv", index=False)

# %%
import pandas as pd

# --- Read the two CSVs ---
# Replace these with your actual file paths
meta_path = "all_mice_GSE64398_metadata.csv"
expr_path = "all_mice_GSE64398.csv"

meta_df = pd.read_csv(meta_path)   # or sep="," depending on your file
expr_df = pd.read_csv(expr_path)   # adjust separator accordingly

# --- Long format: one row per (Sample, Gene) with metadata merged ---

# Melt expression data to long form
long_expr = expr_df.melt(id_vars="ID_REF", var_name="Accession", value_name="Expression")

# Merge metadata
combined_long = long_expr.merge(meta_df, on="Accession", how="left")

# Now combined_long has columns:
# ID_REF (gene), Accession (GSM ID), Expression (value), plus all metadata columns.

# Example: get all rows for GSM1570253
sample_id = "GSM1570253"
sample_long_df = combined_long[combined_long["Accession"] == sample_id]

# print("Long format for sample", sample_id)
# print(sample_long_df.head())

# --- Wide format per sample: single metadata row with all gene expressions as columns ---

# Pivot expression so genes become columns
wide_expr = expr_df.set_index("ID_REF").T  # rows = GSM IDs, columns = genes

# wide_expr index currently are GSM IDs (Accession); ensure name matches for merging
wide_expr.index.name = "Accession"

# Merge with metadata
combined_wide = meta_df.merge(wide_expr, on="Accession", how="left")

# Example: single wide row for GSM1570253
sample_wide_df = combined_wide[combined_wide["Accession"] == sample_id]

# print("Wide format for sample", sample_id)
# print(sample_wide_df.iloc[0, :15])  # show first few columns (metadata + some genes)

# --- Build a dictionary of per-sample DataFrames (long format) ---
sample_long_dfs = {
    acc: df for acc, df in combined_long.groupby("Accession")
}

# Access:
sample_GSM1570253_df = sample_long_dfs["GSM1570253"]

# --- Or dictionary for wide format (each is a single-row DataFrame) ---
sample_wide_dfs = {
    acc: combined_wide[combined_wide["Accession"] == acc] for acc in combined_wide["Accession"]
}

# --- Optional: function helpers ---

def get_sample_long(accession: str) -> pd.DataFrame:
    return combined_long[combined_long["Accession"] == accession].copy()

def get_sample_wide(accession: str) -> pd.DataFrame:
    return combined_wide[combined_wide["Accession"] == accession].copy()

# Example usage:
df_long = get_sample_long("GSM1570253")
print(df_long)
# df_wide = get_sample_wide("GSM1570253")
# Out:
#               ID_REF   Accession  Expression Group Title Source name  \
# 0      0610005K03RIK  GSM1570253     6.43230     -   478         HIP
# 1      0610006F02RIK  GSM1570253     6.48671     -   478         HIP
# 2      0610006I08RIK  GSM1570253    11.52560     -   478         HIP
# 3      0610006K04RIK  GSM1570253     8.89335     -   478         HIP
# 4      0610007C21RIK  GSM1570253    12.08650     -   478         HIP
# ...              ...         ...         ...   ...   ...         ...
# 12553           ZW10  GSM1570253     8.36117     -   478         HIP
# 12554           ZXDA  GSM1570253    10.91640     -   478         HIP
# 12555         ZYG11B  GSM1570253     6.93133     -   478         HIP
# 12556            ZYX  GSM1570253    12.18030     -   478         HIP
# 12557           ZZZ3  GSM1570253     6.55961     -   478         HIP
#
#       Sample section Hybridisation day  Grown with    Genotype  Age_weeks
# 0                  A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 1                  A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 2                  A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 3                  A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 4                  A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# ...              ...               ...         ...         ...        ...
# 12553              A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 12554              A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 12555              A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 12556              A        2013-03-04  HET_TASTPM  HET_TASTPM         32
# 12557              A        2013-03-04  HET_TASTPM  HET_TASTPM         32
#
# [12558 rows x 11 columns]
